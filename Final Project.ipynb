# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv(r'C:\Users\grogers3\Downloads\archive (3)\Scooby-Doo Completed.csv')

# %%
df2 = pd.read_csv(r'C:\Users\grogers3\Downloads\archive (2)\scoobydoo.csv')

# %%
df
# Out:
#      index                 series.name            network season  \
# 0        1  Scooby Doo, Where Are You!                CBS      1
# 1        2  Scooby Doo, Where Are You!                CBS      1
# 2        3  Scooby Doo, Where Are You!                CBS      1
# 3        4  Scooby Doo, Where Are You!                CBS      1
# 4        5  Scooby Doo, Where Are You!                CBS      1
# ..     ...                         ...                ...    ...
# 598    599   Scooby-Doo and Guess Who?          Boomerang      2
# 599    600           Warner Home Video  Warner Home Video  Movie
# 600    601           Warner Home Video  Warner Home Video  Movie
# 601    602   Scooby-Doo and Guess Who?          Boomerang      2
# 602    603   Scooby-Doo and Guess Who?          Boomerang      2
#
#                                     title  imdb  engagement  date.aired  \
# 0               What a Night for a Knight   8.1       556.0  1969-09-13
# ...

# %%
df.drop(['index','split.up','batman','groovy','zoinks', 'another.mystery','set.a.trap','jeepers','jinkies','my.glasses','just.about.wrapped.up','scooby.doo.where.are.you','rooby.rooby.roo','scooby-dum','scrappy-doo','hex.girls','blue.falcon','number.of.snacks','door.gag','and.that','motive','culprit.amount','culprit.name','arrested','non-suspect','suspects.amount','setting.country/state','setting.terrain','trap.work.first','caught.not','snack.fred','snack.daphnie','snack.velma','snack.shaggy','snack.scooby','unmask.other','caught.other'],axis=1,inplace=True)

# %%
df
# Out:
#                     series.name            network season  \
# 0    Scooby Doo, Where Are You!                CBS      1
# 1    Scooby Doo, Where Are You!                CBS      1
# 2    Scooby Doo, Where Are You!                CBS      1
# 3    Scooby Doo, Where Are You!                CBS      1
# 4    Scooby Doo, Where Are You!                CBS      1
# ..                          ...                ...    ...
# 598   Scooby-Doo and Guess Who?          Boomerang      2
# 599           Warner Home Video  Warner Home Video  Movie
# 600           Warner Home Video  Warner Home Video  Movie
# 601   Scooby-Doo and Guess Who?          Boomerang      2
# 602   Scooby-Doo and Guess Who?          Boomerang      2
#
#                                     title  imdb  engagement  date.aired  \
# 0               What a Night for a Knight   8.1       556.0  1969-09-13
# 1                   A Clue for Scooby Doo   8.1       479.0  1969-09-20
# ...

# %%
df.drop([])
