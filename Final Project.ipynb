# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv(r'C:\Users\grogers3\Downloads\archive (3)\Scooby-Doo Completed.csv')

# %%
df.drop(['split.up','batman','groovy','zoinks', 'another.mystery','set.a.trap','jeepers','jinkies','my.glasses','just.about.wrapped.up','scooby.doo.where.are.you','rooby.rooby.roo','scooby-dum','scrappy-doo','hex.girls','blue.falcon','number.of.snacks','door.gag','and.that','motive','culprit.amount','culprit.name','arrested','non-suspect','suspects.amount','setting.country/state','setting.terrain','trap.work.first','caught.not','snack.fred','snack.daphnie','snack.velma','snack.shaggy','snack.scooby','unmask.other','caught.other'],axis=1,inplace=True)

# %%
df.drop(['monster.name','run.time','culprit.gender','monster.gender','daphnie.va','velma.va','shaggy.va','scooby.va','fred.va','monster.species','monster.real','monster.amount','monster.subtype','monster.type','if.it.wasnt.for','caught.daphnie','caught.fred','caught.velma','caught.shaggy','caught.scooby','captured.fred','captured.daphnie','captured.velma','captured.shaggy','captured.scooby','unmask.daphnie','unmask.fred','unmask.velma','unmask.shaggy','unmask.scooby'],axis=1,inplace=True)

# %%
df.drop(['season'],axis=1,inplace=True)

# %%
sns.barplot(data = df, x = 'imdb', y = 'format')
# Out:
# <AxesSubplot:xlabel='imdb', ylabel='format'>

# %%
sns.barplot(data = df, x = 'imdb', y = 'series.name')
# Out:
# <AxesSubplot:xlabel='imdb', ylabel='series.name'>

# %%
sns.lineplot(data = df, x = 'index', y = 'imdb')
# Out:
# <AxesSubplot:xlabel='index', ylabel='imdb'>

# %%
sns.regplot(data = df, y = 'imdb', x = 'index')
# Out:
# <AxesSubplot:xlabel='index', ylabel='imdb'>

# %%
sns.barplot(data = df, x = 'imdb', y = 'network')
# Out:
# <AxesSubplot:xlabel='imdb', ylabel='network'>

# %%
df.drop(['engagement','title',],axis=1,inplace=True)

# %%
df.sort_values(by='imdb',inplace = True, ascending = False)

# %%
df.head(40)
# Out:
#      index                      series.name          network  imdb date.aired  \
# 552    553                     Supernatural           The CW   9.6 2018-03-29
# 482    483  Scooby-Doo Mystery Incorporated  Cartoon Network   9.3 2013-04-05
# 450    451  Scooby-Doo Mystery Incorporated  Cartoon Network   9.2 2011-07-26
# 463    464  Scooby-Doo Mystery Incorporated  Cartoon Network   9.1 2012-08-10
# 481    482  Scooby-Doo Mystery Incorporated  Cartoon Network   9.0 2013-04-05
# 466    467  Scooby-Doo Mystery Incorporated  Cartoon Network   8.9 2012-08-15
# 478    479  Scooby-Doo Mystery Incorporated  Cartoon Network   8.9 2013-04-02
# 477    478  Scooby-Doo Mystery Incorporated  Cartoon Network   8.9 2013-03-29
# 449    450  Scooby-Doo Mystery Incorporated  Cartoon Network   8.8 2011-07-19
# 574    575        Scooby-Doo and Guess Who?        Boomerang   8.8 2020-07-02
# 441    442  Scooby-Doo Mystery Incorporated  Cartoon Network   8.8 2011-05-24
# 480    481  Scooby-Doo Mystery Incorporated  Cartoon Network   8.7 2013-04-04
