# %%
dataLicence = [[True,False,False,False,False,False,True,True,False,False,False,True,True,True,False,False,True,True,False]
               ,["Bus","Bus","Bus","Bus","Bus","Bus","Car","Car","Bus","Car","Bus","Car","Bus","Car","Bus","Bus","Car","Car","Bus"],
              ["Junior","Senior","Junior","Sophmore","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Senior","Junior","Senior","Sophmore","Freshman","Senior","Senior","Sophmore"]]
count = 0
print(True)
for i in dataLicence[0]:
    if i:
        print("*",end='')
        count +=1
print(count)
count=0
print(False)
for i in dataLicence[0]:
    if i == False:
        print("*",end='')
        count += 1
print(count)
print()
count = 0
print("Bus")
for i in dataLicence[1]:
    if i == "Bus":
        print("*",end='')
        count +=1
print(count)
count=0
print("Car")
for i in dataLicence[1]:
    if i == "Car":
        print("*",end='')
        count += 1
print(count)
print()
fcoun=0
scoun=0
jcoun=0
sscoun=0
for i in dataLicence[2]:
    if i == "Senior":
        sscoun += 1
    elif i == "Junior":
        jcoun += 1
    elif i =="Sophmore":
        scoun += 1
    elif i == "Freshman":
        fcoun += 1
print("Freshman")
for i in range(fcoun):
    print("*",end='')
print(fcoun)
print("Sophmore")
for i in range(scoun):
    print("*",end='')
print(scoun)
print("Junior")
for i in range(jcoun):
    print("*",end='')
print(jcoun)
print("Seinor")
for i in range(sscoun):
    print("*",end='')
print(sscoun)
# Out:
# True
# ********8
# False
# ***********11
#
# Bus
# ************12
# Car
# *******7
#
# Freshman
# *1
# Sophmore
# ***3
# Junior
# ******6
# Seinor
# *********9
